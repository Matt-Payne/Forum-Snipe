# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

import pandas as pd
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import re
import numpy as np
import os

#browser = webdriver.Chrome(ChromeDriverManager(version="87.0.4280.88").install())
#browser.get("https://www.google.com")

browser = webdriver.Chrome(r"C:\Users\matt\Documents\chromedriver")
browser.get(url='https://www.net54baseball.com/')
browser.find_element_by_id('navbar_username').send_keys('Goudey')
browser.find_element_by_xpath('//input[@type="password"]').send_keys('****')
browser.find_element_by_xpath("//input[@type='submit']").click()
time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-15-1d5a58206a02> in <module>
#      14 #browser.get("https://www.google.com")
#      15
# ---> 16 browser = webdriver.Chrome(r"C:\Users\matt\Documents\chromedriver")
#      17 browser.get(url='https://www.net54baseball.com/')
#      18 browser.find_element_by_id('navbar_username').send_keys('Goudey')
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ...

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_trf
nlp = en_core_web_trf.load()

doc = nlp('Default FS: 1956 Hank Aaron Gray Back BVG 5.5')
print([(X.text, X.label_) for X in doc.ents])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f782b89a2f65> in <module>
#       3 from collections import Counter
#       4 import en_core_web_trf
# ----> 5 nlp = en_core_web_trf.load()
#       6
#       7 doc = nlp('Default FS: 1956 Hank Aaron Gray Back BVG 5.5')
#
# ~\Anaconda3\lib\site-packages\en_core_web_trf\__init__.py in load(**overrides)
#       8
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# ~\Anaconda3\lib\site-packages\spacy\util.py in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     518         disable=disable,
#     519         exclude=exclude,
# --> 520         config=config,
#     521     )
#     522
#
# ~\Anaconda3\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
# ...
